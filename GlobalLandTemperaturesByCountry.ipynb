# %%
import pandas as pd

# %%
temp = pd.read_csv('GlobalLandTemperaturesByCountry.csv')
temp
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1743-11-01               4.384                          2.294
# 1       1743-12-01                 NaN                            NaN
# 2       1744-01-01                 NaN                            NaN
# 3       1744-02-01                 NaN                            NaN
# 4       1744-03-01                 NaN                            NaN
# ...            ...                 ...                            ...
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
# 577461  2013-09-01                 NaN                            NaN
#
#          Country
# 0          Åland
# 1          Åland
# 2          Åland
# 3          Åland
# 4          Åland
# ...

# %%
temp.columns
# Out:
# Index(['dt', 'AverageTemperature', 'AverageTemperatureUncertainty', 'Country'], dtype='object')

# %%
temp.Country.unique()
# Out:
# array(['Åland', 'Afghanistan', 'Africa', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica',
#        'Antigua And Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Asia',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Baker Island', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belize', 'Benin', 'Bhutan', 'Bolivia',
#        'Bonaire, Saint Eustatius And Saba', 'Bosnia And Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands', 'Bulgaria',
#        'Burkina Faso', 'Burma', 'Burundi', "Côte D'Ivoire", 'Cambodia',
#        'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China',
#        'Christmas Island', 'Colombia', 'Comoros',
#        'Congo (Democratic Republic Of The)', 'Congo', 'Costa Rica',
#        'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czech Republic',
#        'Denmark (Europe)', 'Denmark', 'Djibouti', 'Dominica',
# ...

# %%
temp['dt'] = pd.to_datetime(temp['dt'])

# %%
Germany = temp.loc[temp['Country']=="Germany"]
USA = temp.loc[temp['Country']=="United States"]
Brazil = temp.loc[temp['Country']=="Brazil"]
Australia = temp.loc[temp['Country']=="Australia"]
UK = temp.loc[temp['Country']=="United Kingdom"]
France = temp.loc[temp['Country']=="France"]
Portugal = temp.loc[temp['Country']=="Portugal"]
Sweden = temp.loc[temp['Country']=="Sweden"]
Denmark = temp.loc[temp['Country']=="Denmark"]

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(
                x=Germany['dt'],
                y=Germany['AverageTemperature'],
                name="Germany",
                opacity=0.8))
fig.add_trace(go.Scatter(
                x=USA['dt'],
                y=USA['AverageTemperature'],
                name="USA",
                opacity=0.8))
fig.add_trace(go.Scatter(
                x=England['dt'],
                y=England['AverageTemperature'],
                name="England",
                opacity=0.8))
fig.add_trace(go.Scatter(
                x=Brazil['dt'],
                y=Brazil['AverageTemperature'],
                name="Brazil",
                opacity=0.8))
fig.add_trace(go.Scatter(
                x=Australia['dt'],
                y=Australia['AverageTemperature'],
                name="Australia",
                opacity=0.8))
fig.add_trace(go.Scatter(
                x=France['dt'],
                y=France['AverageTemperature'],
                name="France",
                opacity=0.8))
fig.add_trace(go.Scatter(
                x=Portugal['dt'],
                y=Portugal['AverageTemperature'],
                name="Portugal",
                opacity=0.8))
fig.add_trace(go.Scatter(
                x=Sweden['dt'],
                y=Sweden['AverageTemperature'],
                name="Sweden",
                opacity=0.8))
fig.add_trace(go.Scatter(
                x=Denmark['dt'],
                y=Denmark['AverageTemperature'],
                name="Denmark",
                opacity=0.8))
fig.show()
# Out:
# <div>
#
#
#             <div id="4013aabb-7736-4d84-a052-a677bba065fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4013aabb-7736-4d84-a052-a677bba065fc")) {
#                     Plotly.newPlot(
#                         '4013aabb-7736-4d84-a052-a677bba065fc',
# ...
